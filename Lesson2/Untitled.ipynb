# %%
import pandas as pd
from datetime import datetime

# %%
df = pd.read_csv('/mnt/HC_Volume_18315164/home-jupyter/jupyter-v-kachanovskij-24/Lesson2/lesson_2_data.csv', 
                 encoding = 'windows-1251', sep = ';')

# %%
df
# Out:
#        Номер     Дата создания       Дата оплаты  \
# 0    1062823  01.12.2019 10:50  01.12.2019 10:52
# 1    1062855  01.12.2019 20:53  01.12.2019 21:27
# 2    1062856  01.12.2019 21:43               NaN
# 3    1062880   03.12.2019 0:18               NaN
# 4    1062899  03.12.2019 21:43               NaN
# ..       ...               ...               ...
# 287  1064720   30.12.2019 9:42  30.12.2019 12:49
# 288  1064724  30.12.2019 11:32               NaN
# 289  1064775   31.12.2019 2:17   31.12.2019 2:22
# 290  1064793  31.12.2019 16:40  01.01.2020 14:29
# 291  1064796  31.12.2019 17:29  31.12.2019 17:32
#
#                                                  Title    Статус  Заработано  \
# 0                              Курс обучения «Эксперт»  Завершен    29597.50
# 1                              Курс обучения «Эксперт»  Завершен    17450.30
# 2                           Курс обучения «Специалист»   Отменен        0.00
# ...

# %%
df = df.rename(columns={'Платежная система': 'payment_system', 
                       'Номер': 'number',
                       'Дата создания': 'create_date',
                       'Дата оплаты': 'payment_date', 
                       'Title': 'title', 
                       'Статус': 'status', 
                       'Заработано': 'money', 
                       'Город': 'city'})

# %%
df
# Out:
#       number       create_date      payment_date  \
# 0    1062823  01.12.2019 10:50  01.12.2019 10:52
# 1    1062855  01.12.2019 20:53  01.12.2019 21:27
# 2    1062856  01.12.2019 21:43               NaN
# 3    1062880   03.12.2019 0:18               NaN
# 4    1062899  03.12.2019 21:43               NaN
# ..       ...               ...               ...
# 287  1064720   30.12.2019 9:42  30.12.2019 12:49
# 288  1064724  30.12.2019 11:32               NaN
# 289  1064775   31.12.2019 2:17   31.12.2019 2:22
# 290  1064793  31.12.2019 16:40  01.01.2020 14:29
# 291  1064796  31.12.2019 17:29  31.12.2019 17:32
#
#                                                  title    status     money  \
# 0                              Курс обучения «Эксперт»  Завершен  29597.50
# 1                              Курс обучения «Эксперт»  Завершен  17450.30
# 2                           Курс обучения «Специалист»   Отменен      0.00
# ...

# %%
all_money = df.money.sum()

# %%
money_by_city = df \
    .groupby(['title', 'city'],as_index = False) \
    .aggregate({'money': 'sum'}) \
    .sort_values('money', ascending=False)

# %%
money_by_city.to_csv('money_by_city.csv', index=False)

# %%
money_title = df \
    .query("status == 'Завершен'") \
    .groupby('title',as_index = False) \
    .aggregate({'money': 'sum', 'number': 'count'}) \
    .sort_values('money', ascending=False)

# %%
money_title
# Out:
#                                                title      money  number
# 5  Подписка «ОНЛАЙН ДИЕТОЛОГ» с ежемесячным автос...  366947.20     125
# 0                        Курс обучения «Консультант»  208163.49      31
# 1                         Курс обучения «Специалист»  160862.64       7
# 2                            Курс обучения «Эксперт»  148992.80       5
# 4  Курс от Школы Диетологов. Повышение квалификац...   88384.92       9
# 3                   Курс от Школы Диетологов. Бизнес   18752.54       3

# %%
today_day = datetime.today().strftime('%Y-%m-%d')
file_name ='money_title_{}.csv'
file_name = file_name.format(today_day)

# %%
if int(money_title.money.sum()) == int(all_money):
    print('OK! File {} is written'.format(file_name))
    money_title.to_csv(file_name, index=False)
else:
    print('ERROR')
# Out:
# OK! File money_title_2022-05-23.csv is written

# %%
# Out:
# 'money_title_2022-05-23.csv'

# %%
taxi = pd.read_csv('/mnt/HC_Volume_18315164/home-jupyter/jupyter-v-kachanovskij-24/shared/hall_of_fame/2_taxi_nyc.csv', 
                 encoding = 'windows-1251', parse_dates=['pickup_dt'])

# %%
taxi
# Out:
#                 pickup_dt pickup_month        borough  pickups hday  spd  \
# 0     2015-01-01 01:00:00          Jan          Bronx      152    Y  5.0
# 1     2015-01-01 01:00:00          Jan       Brooklyn     1519    Y  5.0
# 2     2015-01-01 01:00:00          Jan            EWR        0    Y  5.0
# 3     2015-01-01 01:00:00          Jan      Manhattan     5258    Y  5.0
# 4     2015-01-01 01:00:00          Jan         Queens      405    Y  5.0
# ...                   ...          ...            ...      ...  ...  ...
# 29096 2015-06-30 23:00:00          Jun            EWR        0    N  7.0
# 29097 2015-06-30 23:00:00          Jun      Manhattan     3828    N  7.0
# 29098 2015-06-30 23:00:00          Jun         Queens      580    N  7.0
# 29099 2015-06-30 23:00:00          Jun  Staten Island        0    N  7.0
# 29100 2015-06-30 23:00:00          Jun            NaN        3    N  7.0
#
#         vsb  temp  dewp     slp  pcp 01  pcp 06  pcp 24   sd
# ...

# %%
taxi[['borough': 'Brooklin'].value_counts()
# Out:
# Staten Island    4343
# Queens           4343
# EWR              4343
# Brooklyn         4343
# Manhattan        4343
# Bronx            4343
# Name: borough, dtype: int64

# %%
all_pickups = taxi.pickups.sum()

# %%
pickups_by_mon_bor = taxi \
    .groupby(['borough', 'pickup_month'], as_index=False) \
    .agg({'pickups': 'sum'}) \
    .sort_values('pickups', ascending=False) \

# %%
taxi.loc[taxi['hday'] == 'N'] \
    .groupby(['borough', 'hday'], as_index=False) \
    .agg({'pickups': 'mean'}) \
    .sort_values('pickups', ascending=False) \
    .mean()
# Out:
# pickups    2.294943e+06
# dtype: float64

# %%
df_one
# Out:
#       pickup_dt,pickup_month,borough,pickups,hday,spd,vsb,temp,dewp,slp,pcp 01,pcp 06,pcp 24,sd  \
# 0      2015-01-01 01:00:00,Jan,Bronx,152,Y,5.0,10.0,3...
# 1      2015-01-01 01:00:00,Jan,Brooklyn,1519,Y,5.0,10...
# 2      2015-01-01 01:00:00,Jan,EWR,0,Y,5.0,10.0,30.0,...
# 3      2015-01-01 01:00:00,Jan,Manhattan,5258,Y,5.0,1...
# 4      2015-01-01 01:00:00,Jan,Queens,405,Y,5.0,10.0,...
# ...                                                  ...
# 29096  2015-06-30 23:00:00,Jun,EWR,0,N,7.0,10.0,75.0,...
# 29097  2015-06-30 23:00:00,Jun,Manhattan,3828,N,7.0,1...
# 29098  2015-06-30 23:00:00,Jun,Queens,580,N,7.0,10.0,...
# 29099  2015-06-30 23:00:00,Jun,Staten Island,0,N,7.0,...
# 29100  2015-06-30 23:00:00,Jun,,3,N,7.0,10.0,75.0,65....
#
#        new_columns
# 0               14
# 1               14
# 2               14
# 3               14
# 4               14
# ...            ...
# 29096           14
# 29097           14
# 29098           14
# 29099           14
# ...

# %%
df_one[['pickup_dt', 'pickup_mounth', 'borough', 'pickups', 'hday', 'spd', 'vsb', 'temp', 'dewb', 'slp', 'pcp_01', 'pcp_06', 'pcp_24', 'sd']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-46-e46e80a1224d> in <module>
# ----> 1 df_one[['pickup_dt', 'pickup_mounth', 'borough', 'pickups', 'hday', 'spd', 'vsb', 'temp', 'dewb', 'slp', 'pcp_01', 'pcp_06', 'pcp_24', 'sd']]
#
# /opt/tljh/user/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2906             if is_iterator(key):
#    2907                 key = list(key)
# -> 2908             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2909
#    2910         # take() does not accept boolean indexers
#
# /opt/tljh/user/lib/python3.7/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1252             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1253
# ...
