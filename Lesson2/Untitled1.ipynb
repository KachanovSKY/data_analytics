# %%
import pandas as pd
path_to_file = '/mnt/HC_Volume_18315164/home-jupyter/jupyter-v-kachanovskij-24/shared/homeworks/python_ds_miniprojects/2/bookings.csv'
bookings = pd.read_csv(path_to_file, encoding='Windows-1251', sep=';')

# %%
bookings.columns = bookings.columns.str.replace(" ", "_")
bookings.rename(str.lower, axis='columns', inplace=True)
bookings
# Out:
#                hotel  is_canceled  lead_time arrival_full_date  \
# 0       Resort Hotel            0        342        2015-07-01
# 1       Resort Hotel            0        737        2015-07-01
# 2       Resort Hotel            0          7        2015-07-01
# 3       Resort Hotel            0         13        2015-07-01
# 4       Resort Hotel            0         14        2015-07-01
# ...              ...          ...        ...               ...
# 119385    City Hotel            0         23        2017-08-30
# 119386    City Hotel            0        102        2017-08-31
# 119387    City Hotel            0         34        2017-08-31
# 119388    City Hotel            0        109        2017-08-31
# 119389    City Hotel            0        205        2017-08-29
#
#         arrival_date_year arrival_date_month  arrival_date_week_number  \
# 0                    2015               July                        27
# ...

# %%
bookings['total_kids'] = bookings.children + bookings.babies
bookings['has_kids'] = False
if

# %%
top_country = bookings\
    .groupby('hotel')\
    .aggregate({'total_kids': 'mean'})\
    .round(2)

# %%
top_country
# Out:
#               total_kids
# hotel
# City Hotel          0.10
# Resort Hotel        0.14

# %%
top_country = bookings \
    .query("reservation_status != 'Check-Out' and hotel == 'City Hotel' and arrival_date_year == '2016'")\
    .groupby(['arrival_date_month']).count()\
    .sort_values('hotel', ascending=False)

# %%
top_country
# Out:
#                     hotel  is_canceled  lead_time  arrival_full_date  \
# arrival_date_month
# October              1947         1947       1947               1947
# June                 1720         1720       1720               1720
# September            1567         1567       1567               1567
# April                1539         1539       1539               1539
# May                  1436         1436       1436               1436
# November             1360         1360       1360               1360
# August               1247         1247       1247               1247
# March                1108         1108       1108               1108
# December             1072         1072       1072               1072
# July                 1043         1043       1043               1043
# February              930          930        930                930
# January               438          438        438                438
#
# ...
