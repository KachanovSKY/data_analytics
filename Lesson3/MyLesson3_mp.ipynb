# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
user_data_df = pd.read_csv('/mnt/HC_Volume_18315164/home-jupyter/jupyter-v-kachanovskij-24/Lesson3/user_data.csv', encoding='windows-1251')

# %%
logs_df = pd.read_csv('/mnt/HC_Volume_18315164/home-jupyter/jupyter-v-kachanovskij-24/Lesson3/logs.csv', encoding='windows-1251')

# %%
logs_df
# Out:
#       client  success  platform        time
# 0      40177     True     phone  1585412212
# 1      61468     True     phone  1585425658
# 2      35604    False     phone  1585459894
# 3       9961     True     phone  1585400189
# 4      10931     True  computer  1585468629
# ...      ...      ...       ...         ...
# 4495   64496    False  computer  1585459072
# 4496   73299     True     phone  1585458370
# 4497    8967     True     phone  1585465121
# 4498   52880    False     phone  1585455362
# 4499   40921     True     phone  1585437692
#
# [4500 rows x 4 columns]

# %%
user_data_df
# Out:
#       client  premium  age
# 0      46346    False   58
# 1       4391    False   55
# 2      27372    False   64
# 3      11989    False   44
# 4      60664    False   49
# ...      ...      ...  ...
# 2949   19411    False   29
# 2950   61579    False   50
# 2951   61221     True   64
# 2952   29863    False   46
# 2953   78499    False   36
#
# [2954 rows x 3 columns]

# %%
new_df= logs_df.groupby('platform').agg({'platform': 'count'})
new_df
# Out:
#           platform
# platform
# computer      1505
# phone         2753
# tablet         242

# %%
all_df = logs_df.merge(user_data_df, on='client', how='inner').query("success == True").query("platform == 'computer'").groupby('age', as_index=False).agg({'success':'count'})
all_df.sort_values('success', ascending=False)
# Out:
#     age  success
# 8    28       49
# 29   49       33
# 5    25       33
# 12   32       27
# 48   68       26
# 4    24       26
# 49   69       24
# 45   65       23
# 32   52       22
# 34   54       22
# 39   59       20
# 28   48       19
# 23   43       19
# 15   35       19
# 42   62       18
# 24   44       18
# 17   37       17
# 38   58       17
# 9    29       17
# 13   33       17
# 44   64       16
# 22   42       16
# 41   61       16
# 26   46       16
# 27   47       16
# 37   57       15
# 40   60       15
# 3    23       15
# 31   51       15
# 47   67       15
# 1    21       15
# 20   40       15
# 7    27       14
# 6    26       14
# 11   31       14
# 43   63       14
# 30   50       13
# 18   38       13
# 16   36       12
# 0    20       11
# 19   39       11
# 25   45       11
# 21   41       10
# 14   34       10
# 35   55        9
# 46   66        9
# 10   30        8
# 2    22        8
# 36   56        6
# 33   53        5

# %%
plt.figure(figsize=(12, 8))
sns.countplot(x="age", data=all_df)

# %%
all_df
# Out:
#       client  success
# 0         40        1
# 1         75        1
# 2         81        1
# 3        132        1
# 4        164        1
# ...      ...      ...
# 2099   99908        1
# 2100   99926        1
# 2101   99927        1
# 2102   99931        1
# 2103   99973        1
#
# [2104 rows x 2 columns]

# %%
sns.distplot(all_df)
# Out:
# /opt/tljh/user/lib/python3.7/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.displot(all_df.query("premium == True"))

# %%
new_client_count_df = new_df.query("client == 41")

# %%
new_client_count_df.index
# Out:
# Int64Index([12179, 28719, 36165, 52870, 61468, 61473, 78349, 82563, 92584], dtype='int64', name='client')

# %%
new_df
# Out:
#         client  client_count
# client
# 40           1           NaN
# 50           1           NaN
# 75           1           NaN
# 81           1           NaN
# 132          1           NaN
# ...        ...           ...
# 99926        1           NaN
# 99927        1           NaN
# 99931        1           NaN
# 99973        1           NaN
# 99993        1           NaN
#
# [2845 rows x 2 columns]
