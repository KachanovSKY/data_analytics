# %%
import pandas as pd
import datetime
import vk_api
import os
import requests
import json
import random
import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import sys
from urllib.parse import urlencode

from io import BytesIO

# %%
r = requests.get('https://collectionapi.metmuseum.org/public/collection/v1/search?q=sunflowers')
res = r.json()

# %%
sunflower_ids = res['objectIDs']
sunflower_ids
# Out:
# [436524,
#  484935,
#  437112,
#  210191,
#  431264,
#  397949,
#  656530,
#  480725,
#  486590,
#  375281,
#  485308,
#  705155,
#  11922,
#  2032,
#  816522,
#  343052,
#  208554,
#  20141,
#  403496,
#  360837,
#  2019,
#  400581,
#  423400,
#  707887,
#  761604,
#  207869,
#  437115,
#  223828,
#  682927,
#  57922,
#  649813,
#  79739,
#  193938,
#  339347,
#  208218,
#  437984,
#  202228,
#  436534,
#  696949,
#  704667,
#  437329,
#  436252,
#  436580,
#  437526,
#  363282,
#  190739,
#  207753,
#  347980,
#  822570,
#  487043,
#  203893,
#  367434,
#  423237,
#  839296,
#  262423,
#  367817,
#  13644,
#  820022,
#  648617,
#  761731,
#  814626,
#  207967,
#  626832,
#  262430,
#  262428,
#  707697,
#  205386,
#  262378,
#  426804,
#  664519,
#  633526,
#  747779,
#  369073,
#  436529,
#  436121,
#  436144,
#  852414,
#  427872,
#  436530,
#  436535,
#  437980,
#  724844,
#  834585,
#  834580,
#  834765]

# %%
for i in sunflower_ids:
    if i == 2032:
        print('yes')
# Out:
# yes

# %%
r_test = requests.get(f'https://collectionapi.metmuseum.org/public/collection/v1/objects/437980')
obj_test = r_test.json()

# %%
obj_test
# Out:
# {'objectID': 437980,
#  'isHighlight': False,
#  'accessionNumber': '49.30',
#  'accessionYear': '1949',
#  'isPublicDomain': True,
#  'primaryImage': 'https://images.metmuseum.org/CRDImages/ep/original/DP130999.jpg',
#  'primaryImageSmall': 'https://images.metmuseum.org/CRDImages/ep/web-large/DP130999.jpg',
#  'additionalImages': [],
#  'constituents': [{'constituentID': 161947,
#    'role': 'Artist',
#    'name': 'Vincent van Gogh',
#    'constituentULAN_URL': 'http://vocab.getty.edu/page/ulan/500115588',
#    'constituentWikidata_URL': 'https://www.wikidata.org/wiki/Q5582',
#    'gender': ''}],
#  'department': 'European Paintings',
#  'objectName': 'Painting',
#  'title': 'Cypresses',
#  'culture': '',
#  'period': '',
#  'dynasty': '',
#  'reign': '',
#  'portfolio': '',
#  'artistRole': 'Artist',
#  'artistPrefix': '',
#  'artistDisplayName': 'Vincent van Gogh',
#  'artistDisplayBio': 'Dutch, Zundert 1853–1890 Auvers-sur-Oise',
#  'artistSuffix': '',
# ...

# %%
obj_test['culture']
# Out:
# ''

# %%
tmp_data = pd.Series()
tmp = 0


stra = f'https://collectionapi.metmuseum.org/public/collection/v1/objects/%s'%(sunflower_ids[tmp])
r_test = requests.get(stra)
obj_test = r_test.json()

objectID = obj_test['objectID']
title = obj_test['title']
artistDisplayName = obj_test['artistDisplayName']
department = obj_test['department']
objectBeginDate = obj_test['objectBeginDate']
objectEndDate = obj_test['objectEndDate']
period = obj_test['period']
objectName = obj_test['objectName']
culture = obj_test['culture']

tmp_data = [{'objectID':objectID, 'title':title, 'artistDisplayName':artistDisplayName, 'department':department, 'objectBeginDate':objectBeginDate, 'objectEndDate':objectEndDate, 'period':period,'objectName':objectName, 'culture':culture}]
tmp = tmp+1

    
for i in range(84):
    stra = f'https://collectionapi.metmuseum.org/public/collection/v1/objects/%s'%(sunflower_ids[tmp])
    r_test = requests.get(stra)
    obj_test = r_test.json()
    try:
        objectID = obj_test['objectID']
        title = obj_test['title']
        artistDisplayName = obj_test['artistDisplayName']
        department = obj_test['department']
        objectBeginDate = obj_test['objectBeginDate']
        objectEndDate = obj_test['objectEndDate']
        period = obj_test['period']
        objectName = obj_test['objectName']
        culture = obj_test['culture']
    except:
        continue
    tmp_data += [{'objectID':objectID, 'title':title, 'artistDisplayName':artistDisplayName, 'department':department, 'objectBeginDate':objectBeginDate, 'objectEndDate':objectEndDate, 'period':period,'objectName':objectName, 'culture':culture}]
    tmp = tmp+1
    
dframe = pd.DataFrame(tmp_data)
# Out:
# /opt/tljh/user/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   """Entry point for launching an IPython kernel.

# %%
i = 0
str = 'https://collectionapi.metmuseum.org/public/collection/v1/objects/{}'.format(i)
r_test = requests.get(str)
obj_test = r_test.json()
obj_test
# Out:
# {'message': 'ObjectID not found'}

# %%
tmp_data
# Out:
# [{'objectID': 436524,
#   'title': 'Sunflowers',
#   'artistDisplayName': 'Vincent van Gogh',
#   'department': 'European Paintings',
#   'objectBeginDate': 1887,
#   'objectEndDate': 1887,
#   'period': '',
#   'objectName': 'Painting',
#   'culture': ''},
#  {'objectID': 484935,
#   'title': 'Sunflowers',
#   'artistDisplayName': 'Edward McKnight Kauffer',
#   'department': 'Modern and Contemporary Art',
#   'objectBeginDate': 1921,
#   'objectEndDate': 1921,
#   'period': '',
#   'objectName': 'Painting',
#   'culture': ''},
#  {'objectID': 437112,
#   'title': 'Bouquet of Sunflowers',
#   'artistDisplayName': 'Claude Monet',
#   'department': 'European Paintings',
#   'objectBeginDate': 1881,
#   'objectEndDate': 1881,
#   'period': '',
#   'objectName': 'Painting',
#   'culture': ''},
#  {'objectID': 210191,
#   'title': 'Vase with sunflowers',
#   'artistDisplayName': 'Rozenburg Plateelfabriek',
#   'department': 'European Sculpture and Decorative Arts',
# ...

# %%
dframe
# Out:
#     objectID                                              title  \
# 0     436524                                         Sunflowers
# 1     484935                                         Sunflowers
# 2     437112                              Bouquet of Sunflowers
# 3     210191                               Vase with sunflowers
# 4     431264                                         Sunflowers
# 5     397949                                         Sunflowers
# 6     656530                                         Sunflowers
# 7     480725                                   Large Sunflowers
# 8     486590                                Moroccan Sunflowers
# 9     375281                              Walk Among Sunflowers
# 10    485308                                          Sunflower
# 11    705155                Fan Design with Cats and Sunflowers
# 12     11922                                             Clytie
# 13      2032                                  Chest with drawer
# ...

# %% [markdown]
# ##  FINALE

# %%
for i in range(10):
    r = requests.get('https://collectionapi.metmuseum.org/public/collection/v1/search?departmentId=6&q=cat')
    cats = r.json()
    cat_ids.append(cats)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-182-1e1c9628c367> in <module>
#       2     r = requests.get('https://collectionapi.metmuseum.org/public/collection/v1/search?departmentId=6&q=cat')
#       3     cats = r.json()
# ----> 4     cat_ids.append(cats)
#
# NameError: name 'cat_ids' is not defined

# %%
r = requests.get('https://collectionapi.metmuseum.org/public/collection/v1/search?departmentId=6&q=cat')
cats = r.json()
cats
# Out:
# {'total': 2856,
#  'objectIDs': [49698,
#   49470,
#   53222,
#   36221,
#   60873,
#   70541,
#   752008,
#   43402,
#   47358,
#   49467,
#   54747,
#   54626,
#   55919,
#   59775,
#   55923,
#   36075,
#   50826,
#   57204,
#   53653,
#   42922,
#   56602,
#   47051,
#   47052,
#   72842,
#   69780,
#   59121,
#   38952,
#   39199,
#   38177,
#   59903,
#   59763,
#   73809,
#   49050,
#   58462,
#   54540,
#   45282,
#   39092,
#   38160,
#   38162,
#   38994,
#   53441,
#   55948,
#   54124,
#   59248,
#   36411,
#   58779,
#   73046,
#   38949,
#   671015,
#   45065,
#   42932,
#   56780,
#   42915,
#   59249,
#   36346,
#   51660,
#   670898,
#   55914,
#   39764,
#   55967,
#   69410,
#   68841,
#   55148,
#   76442,
#   37011,
#   36621,
#   58218,
#   54445,
#   57560,
#   56070,
#   41681,
#   53590,
#   58002,
#   45667,
#   50827,
#   46723,
#   36539,
#   54809,
#   38951,
#   38176,
#   38462,
#   38158,
#   38293,
#   38315,
#   38452,
#   39698,
#   39699,
# ...

# %%
cat_ids = cats['objectIDs']
cat_ids
# Out:
# [49698,
#  49470,
#  53222,
#  36221,
#  60873,
#  70541,
#  752008,
#  43402,
#  47358,
#  49467,
#  54747,
#  54626,
#  55919,
#  59775,
#  55923,
#  36075,
#  50826,
#  57204,
#  53653,
#  42922,
#  56602,
#  47051,
#  47052,
#  72842,
#  69780,
#  59121,
#  38952,
#  39199,
#  38177,
#  59903,
#  59763,
#  73809,
#  49050,
#  58462,
#  54540,
#  45282,
#  39092,
#  38160,
#  38162,
#  38994,
#  53441,
#  55948,
#  54124,
#  59248,
#  36411,
#  58779,
#  73046,
#  38949,
#  671015,
#  45065,
#  42932,
#  56780,
#  42915,
#  59249,
#  36346,
#  51660,
#  670898,
#  55914,
#  39764,
#  55967,
#  69410,
#  68841,
#  55148,
#  76442,
#  37011,
#  36621,
#  58218,
#  54445,
#  57560,
#  56070,
#  41681,
#  53590,
#  58002,
#  45667,
#  50827,
#  46723,
#  36539,
#  54809,
#  38951,
#  38176,
#  38462,
#  38158,
#  38293,
#  38315,
#  38452,
#  39698,
#  39699,
#  52995,
#  57106,
#  75200,
#  52994,
#  53005,
#  70582,
#  73158,
#  50780,
#  53422,
#  671014,
#  670965,
#  75747,
# ...

# %%
tmp_data = pd.Series()
tmp = 0

stra = f'https://collectionapi.metmuseum.org/public/collection/v1/objects/%s'%(cat_ids[tmp])
r_test = requests.get(stra)
obj_test = r_test.json()

objectID = obj_test['objectID']
title = obj_test['title']
artistDisplayName = obj_test['artistDisplayName']
department = obj_test['department']
objectBeginDate = obj_test['objectBeginDate']
objectEndDate = obj_test['objectEndDate']
period = obj_test['period']
objectName = obj_test['objectName']
culture = obj_test['culture']

tmp_data = [{'objectID':objectID, 'title':title, 'artistDisplayName':artistDisplayName, 'department':department, 'objectBeginDate':objectBeginDate, 'objectEndDate':objectEndDate, 'period':period,'objectName':objectName, 'culture':culture}]
tmp = tmp+1

    
for i in range(999):
    stra = f'https://collectionapi.metmuseum.org/public/collection/v1/objects/%s'%(cat_ids[tmp])
    r_test = requests.get(stra)
    obj_test = r_test.json()
    try:
        objectID = obj_test['objectID']
        title = obj_test['title']
        artistDisplayName = obj_test['artistDisplayName']
        department = obj_test['department']
        objectBeginDate = obj_test['objectBeginDate']
        objectEndDate = obj_test['objectEndDate']
        period = obj_test['period']
        objectName = obj_test['objectName']
        culture = obj_test['culture']
    except:
        continue
    tmp_data += [{'objectID':objectID, 'title':title, 'artistDisplayName':artistDisplayName, 'department':department, 'objectBeginDate':objectBeginDate, 'objectEndDate':objectEndDate, 'period':period,'objectName':objectName, 'culture':culture}]
    tmp = tmp+1
    
dframe = pd.DataFrame(tmp_data)
# Out:
# /opt/tljh/user/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   """Entry point for launching an IPython kernel.

# %%
dframe.groupby('period', as_index = False).agg({'objectID':'count'}).sort_values('objectID')
# Out:
#                                                period  objectID
# 55                       Ming dynasty (?) (1368–1644)         1
# 60                          Mughal period (1526–1858)         1
# 98                      Western Jin dynasty (265–316)         1
# 57     Momoyama (1573–1615) or Edo (1615–1868) period         1
# 56  Ming dynasty(1368–1644), Xuande mark and perio...         1
# ..                                                ...       ...
# 40                           Meiji period (1868–1912)        33
# 43                           Ming dynasty (1368–1644)        43
# 74                           Qing dynasty (1644–1911)        50
# 0                                                            93
# 14                             Edo period (1615–1868)       471
#
# [111 rows x 2 columns]
